# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 631

# %%
# # Build query URL
city_data=[]

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
cities[16]
# Out:
# 'bredasdorp'

# %%
# Loop through all the cities in our list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city

    # Log the url, record, and set numbers
    print((record_count, set_count, city))

    record_count += 1

    try:
        #Api call
        city_weather = requests.get(city_url).json()


        #Parsing API
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]


        #Append city info

        city_data.append({"City": city, 
                        "Country":city_country,
                        "Lat": city_lat,
                        "Lng": city_lng, 
                        "Max Temp":city_max_temp,
                        "Cloudiness":city_clouds,
                        "Humidity":city_humidity,
                        "Date":city_date
                         })

    except:
        print("city not found")
        pass

print("-----------------------------")
print("Data retrieval complete")
print("------------------------------")
# Out:
# (17, 1, 'ushuaia')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (18, 1, 'albany')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (19, 1, 'tuatapere')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (20, 1, 'iqaluit')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (21, 1, 'airai')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (22, 1, 'punta arenas')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (23, 1, 'fortuna')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (24, 1, 'rikitea')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (25, 1, 'hobart')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (26, 1, 'torbay')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (27, 1, 'razole')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (28, 1, 'margate')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (29, 1, 'port alfred')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (30, 1, 'ilulissat')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (31, 1, 'cape town')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (32, 1, 'taolanaro')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (33, 1, 'bredasdorp')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (34, 1, 'avarua')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (35, 1, 'saleaula')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (36, 1, 'khatanga')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (37, 1, 'selenginsk')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (38, 1, 'avera')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (39, 1, 'chapais')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (40, 1, 'kapaa')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (41, 1, 'sao filipe')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (42, 1, 'bargal')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (43, 1, 'nizhneyansk')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (44, 1, 'rocha')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (45, 1, 'grand river south east')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (46, 1, 'xining')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (47, 1, 'nyurba')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (48, 1, 'busselton')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (49, 1, 'castro')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (50, 1, 'padang')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (51, 1, 'mataura')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (52, 1, 'nikolskoye')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (53, 1, 'illoqqortoormiut')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (54, 1, 'namibe')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (55, 1, 'ahipara')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (56, 1, 'dhidhdhoo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (57, 1, 'ossora')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (58, 1, 'tiksi')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (59, 1, 'half moon bay')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (60, 1, 'saskylakh')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (61, 1, 'natal')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (62, 1, 'shibarghan')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (63, 1, 'barrow')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (64, 1, 'okhotsk')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (65, 1, 'palabuhanratu')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (66, 1, 'atuona')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (0, 2, 'raudeberg')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (1, 2, 'ust-kulom')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (2, 2, 'clyde river')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (3, 2, 'hermanus')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (4, 2, 'dikson')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (5, 2, 'kutum')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (6, 2, 'vestmannaeyjar')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (7, 2, 'bam')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (8, 2, 'new norfolk')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (9, 2, 'waipawa')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (10, 2, 'cockburn town')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (11, 2, 'vaini')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (12, 2, 'qasigiannguit')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (13, 2, 'pumiao')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (14, 2, 'chokurdakh')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (15, 2, 'marsh harbour')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (16, 2, 'maniitsoq')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (17, 2, 'vardo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (18, 2, 'leningradskiy')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (19, 2, 'tsihombe')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (20, 2, 'codrington')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (21, 2, 'altay')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (22, 2, 'lebu')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (23, 2, 'puerto ayora')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (24, 2, 'luderitz')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (25, 2, 'arraial do cabo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (26, 2, 'mont-dore')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (27, 2, 'nabire')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (28, 2, 'isangel')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (29, 2, 'blackwater')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (30, 2, 'panama city')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (31, 2, 'kaitangata')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (32, 2, 'sidhauli')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (33, 2, 'farafenni')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (34, 2, 'udarnyy')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (35, 2, 'kununurra')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (36, 2, 'neuquen')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (37, 2, 'taoudenni')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (38, 2, 'sola')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (39, 2, 'hithadhoo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (40, 2, 'sanming')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (41, 2, 'pailon')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (42, 2, 'nishihara')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (43, 2, 'pacific grove')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (44, 2, 'orange cove')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (45, 2, 'chuy')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (46, 2, 'presidencia roque saenz pena')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (47, 2, 'carbonia')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (48, 2, 'kodiak')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (49, 2, 'alyangula')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (0, 3, 'bitung')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (1, 3, 'provideniya')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (2, 3, 'hasaki')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (3, 3, 'ha tinh')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (4, 3, 'gigmoto')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (5, 3, 'norman wells')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (6, 3, 'dingle')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (7, 3, 'pacifica')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (8, 3, 'kachiry')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (9, 3, 'san policarpo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (10, 3, 'oranjemund')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (11, 3, 'qaanaaq')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (12, 3, 'kushiro')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (13, 3, 'manono')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (14, 3, 'hamilton')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (15, 3, 'reefton')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (16, 3, 'maxixe')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (17, 3, 'konin')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (18, 3, 'georgetown')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (19, 3, 'sentyabrskiy')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (20, 3, 'orkney')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (21, 3, 'bloomsburg')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (22, 3, 'meulaboh')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (23, 3, 'pervomayskoye')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (24, 3, 'mahebourg')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (25, 3, 'rania')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (26, 3, 'mullaitivu')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (27, 3, 'matara')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (28, 3, 'wanaka')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (29, 3, 'xai-xai')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (30, 3, 'faanui')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (31, 3, 'astana')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (32, 3, 'romblon')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (33, 3, 'quang ngai')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (34, 3, 'san patricio')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (35, 3, 'shu')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (36, 3, 'hilo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (37, 3, 'nanortalik')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (38, 3, 'vaitupu')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (39, 3, 'muros')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (40, 3, 'auki')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (41, 3, 'sabang')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (42, 3, 'wum')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (43, 3, 'othonoi')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (44, 3, 'esperance')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (45, 3, 'nelson bay')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (46, 3, 'klaksvik')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (47, 3, 'amderma')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (48, 3, 'vila franca do campo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (49, 3, 'yellowknife')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (0, 4, 'monrovia')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (1, 4, 'caucaia')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (2, 4, 'weinan')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (3, 4, 'san')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (4, 4, 'sai buri')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (5, 4, 'jamestown')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (6, 4, 'ponta do sol')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (7, 4, 'coahuayana')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (8, 4, 'pevek')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (9, 4, 'birobidzhan')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (10, 4, 'bilibino')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (11, 4, 'huimanguillo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (12, 4, 'longyearbyen')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (13, 4, 'el real de santa maria')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (14, 4, 'bambous virieux')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (15, 4, 'saint george')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (16, 4, 'vila velha')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (17, 4, 'mumford')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (18, 4, 'snyder')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (19, 4, 'kruisfontein')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (20, 4, 'nemuro')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (21, 4, 'yar-sale')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (22, 4, 'bonavista')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (23, 4, 'balkanabat')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (24, 4, 'sioux lookout')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (25, 4, 'campobello di mazara')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (26, 4, 'tautira')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (27, 4, 'carutapera')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (28, 4, 'port hardy')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (29, 4, 'halifax')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (30, 4, 'caceres')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (31, 4, 'jiwani')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (32, 4, 'hambantota')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (33, 4, 'mengyin')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (34, 4, 'oktyabrskiy')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (35, 4, 'tamandare')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (36, 4, 'linxia')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (37, 4, 'skjervoy')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (38, 4, 'tuktoyaktuk')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (39, 4, 'bolobo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (40, 4, 'turukhansk')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (41, 4, 'phan rang')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (42, 4, 'denpasar')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (43, 4, 'rasra')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (44, 4, 'kamaishi')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (45, 4, 'butaritari')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (46, 4, 'postojna')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (47, 4, 'victoria')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (48, 4, 'praia da vitoria')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (49, 4, 'liverpool')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (0, 5, 'noumea')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (1, 5, 'odessa')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (2, 5, 'vanavara')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (3, 5, 'kisangani')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (4, 5, 'asosa')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (5, 5, 'havelock')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (6, 5, 'belushya guba')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (7, 5, 'nome')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (8, 5, 'banjar')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (9, 5, 'sur')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (10, 5, 'lavrentiya')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (11, 5, 'taseyevo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (12, 5, 'makakilo city')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (13, 5, 'kinkala')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (14, 5, 'saint-augustin')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (15, 5, 'petukhovo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (16, 5, 'sagua la grande')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (17, 5, 'husavik')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (18, 5, 'walvis bay')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (19, 5, 'tabiauea')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (20, 5, 'winton')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (21, 5, 'ejido')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (22, 5, 'carnarvon')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (23, 5, 'lasa')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (24, 5, 'cherskiy')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (25, 5, 'palmer')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (26, 5, 'nha trang')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (27, 5, 'cidreira')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (28, 5, 'esmeraldas')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (29, 5, 'severo-kurilsk')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (30, 5, 'kavaratti')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (31, 5, 'mogzon')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (32, 5, 'sembe')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (33, 5, 'chingirlau')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (34, 5, 'jalalpur jattan')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (35, 5, 'constitucion')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (36, 5, 'jalu')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (37, 5, 'marzuq')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (38, 5, 'portland')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (39, 5, 'kahului')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (40, 5, 'petropavlovsk-kamchatskiy')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (41, 5, 'touros')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (42, 5, 'takoradi')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (43, 5, 'bluff')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (44, 5, 'thompson')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (45, 5, 'kegayli')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (46, 5, 'bouza')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (47, 5, 'umzimvubu')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (48, 5, 'guia de isora')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (49, 5, 'general pico')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (0, 6, 'kangalassy')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (1, 6, 'general salgado')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (2, 6, 'guerrero negro')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (3, 6, 'valparaiso')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (4, 6, 'east london')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (5, 6, 'laguna')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (6, 6, 'comodoro rivadavia')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (7, 6, 'boyolangu')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (8, 6, 'dunedin')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (9, 6, 'ancud')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (10, 6, 'garowe')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (11, 6, 'faya')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (12, 6, 'diamantino')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (13, 6, 'sungurlu')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (14, 6, 'upernavik')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (15, 6, 'brazzaville')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (16, 6, 'tual')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (17, 6, 'barentsburg')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (18, 6, 'troyes')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (19, 6, 'alice springs')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (20, 6, 'mareeba')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (21, 6, 'strezhevoy')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (22, 6, 'iasmos')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (23, 6, 'rawlins')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (24, 6, 'mys shmidta')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (25, 6, 'yumen')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (26, 6, 'beringovskiy')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (27, 6, 'lopukhiv')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (28, 6, 'attawapiskat')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (29, 6, 'los llanos de aridane')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (30, 6, 'ambon')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (31, 6, 'jackson')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (32, 6, 'yelabuga')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (33, 6, 'tumannyy')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (34, 6, 'bolungarvik')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (35, 6, 'victor harbor')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (36, 6, 'sorvag')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (37, 6, 'yomitan')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (38, 6, 'gwanda')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (39, 6, 'batemans bay')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (40, 6, 'neutraubling')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (41, 6, 'mar del plata')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (42, 6, 'mount gambier')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (43, 6, 'norton')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (44, 6, 'groton')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (45, 6, 'geri')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (46, 6, 'tiarei')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (47, 6, 'kadhan')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (48, 6, 'state college')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (49, 6, 'ayan')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (0, 7, 'santa isabel do rio negro')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (1, 7, 'atar')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (2, 7, 'devrek')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (3, 7, 'samarai')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (4, 7, 'marcona')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (5, 7, 'yerbogachen')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (6, 7, 'suez')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (7, 7, 'aklavik')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (8, 7, 'krasnyy yar')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (9, 7, 'quchan')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (10, 7, 'saint-philippe')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (11, 7, 'thunder bay')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (12, 7, 'sao joao da barra')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (13, 7, 'narsaq')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (14, 7, 'nizhniy odes')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (15, 7, 'paysandu')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (16, 7, 'caravelas')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (17, 7, 'vanimo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (18, 7, 'bako')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (19, 7, 'ribeira grande')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (20, 7, 'san cristobal')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (21, 7, 'samusu')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (22, 7, 'sumbe')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (23, 7, 'mocambique')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (24, 7, 'gorontalo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (25, 7, 'nuuk')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (26, 7, 'souillac')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (27, 7, 'erzin')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (28, 7, 'port elizabeth')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (29, 7, 'srostki')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (30, 7, 'borba')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (31, 7, 'shimoda')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (32, 7, 'rawson')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (33, 7, 'okahandja')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (34, 7, 'lagoa')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (35, 7, 'baykit')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (36, 7, 'mwene-ditu')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (37, 7, 'santa rosa')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (38, 7, 'salinopolis')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (39, 7, 'smithers')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (40, 7, 'poya')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (41, 7, 'ridgecrest')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (42, 7, 'ayia galini')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (43, 7, 'koumac')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (44, 7, 'salinas')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (45, 7, 'konigstein')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (46, 7, 'belaya gora')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (47, 7, 'sibu')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (48, 7, 'magdalena')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (49, 7, 'bandar-e torkaman')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (0, 8, 'rudsar')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (1, 8, 'bouake')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (2, 8, 'olinda')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (3, 8, 'darhan')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (4, 8, 'west bay')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (5, 8, 'bethel')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (6, 8, 'miramar')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (7, 8, 'kaihua')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (8, 8, 'maryborough')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (9, 8, 'kavieng')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (10, 8, 'sycow')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (11, 8, 'kokopo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (12, 8, 'anadyr')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (13, 8, 'nsukka')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (14, 8, 'betafo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (15, 8, 'berlevag')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (16, 8, 'ciudad dario')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (17, 8, 'nizwa')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (18, 8, 'santiago del estero')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (19, 8, 'saint-michel-des-saints')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (20, 8, 'latung')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (21, 8, 'trelew')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (22, 8, 'igrim')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (23, 8, 'barabash')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (24, 8, 'panguna')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (25, 8, 'terney')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (26, 8, 'ta khmau')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (27, 8, 'majene')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (28, 8, 'fort nelson')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (29, 8, 'ko samui')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (30, 8, 'paragominas')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (31, 8, 'komyshuvakha')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (32, 8, 'rincon')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (33, 8, 'general roca')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (34, 8, 'verkhoyansk')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (35, 8, 'diego de almagro')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (36, 8, 'bilma')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (37, 8, 'ostrovnoy')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (38, 8, 'gamba')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (39, 8, 'umba')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (40, 8, 'kajaani')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (41, 8, 'arman')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (42, 8, 'vikhorevka')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (43, 8, 'zhigansk')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (44, 8, 'durban')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (45, 8, 'tasiilaq')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (46, 8, 'lompoc')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (47, 8, 'champerico')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (48, 8, 'nouadhibou')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (49, 8, 'saldanha')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (0, 9, 'maraba')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (1, 9, 'soyo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (2, 9, 'yining')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (3, 9, 'dalvik')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (4, 9, 'ribeira brava')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (5, 9, 'okha')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (6, 9, 'grindavik')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (7, 9, 'najran')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (8, 9, 'inongo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (9, 9, 'bibiani')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (10, 9, 'camacha')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (11, 9, 'hualmay')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (12, 9, 'matai')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (13, 9, 'preston')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (14, 9, 'boulder city')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (15, 9, 'karpogory')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (16, 9, 'otradnoye')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (17, 9, 'kumluca')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (18, 9, 'assiniboia')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (19, 9, 'wagar')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (20, 9, 'fare')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (21, 9, 'pemba')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (22, 9, 'cayenne')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (23, 9, 'juifang')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (24, 9, 'ust-kuyga')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (25, 9, 'troitsko-pechorsk')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (26, 9, 'palauig')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (27, 9, 'te anau')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (28, 9, 'boa vista')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (29, 9, 'concordia')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (30, 9, 'stratford')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (31, 9, 'sibolga')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (32, 9, 'bardiyah')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (33, 9, 'coquimbo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (34, 9, 'hun')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (35, 9, 'port lavaca')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (36, 9, 'kikwit')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (37, 9, 'linfen')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (38, 9, 'jambi')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (39, 9, 'coralville')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (40, 9, 'ukiah')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (41, 9, 'tommot')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (42, 9, 'bonthe')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (43, 9, 'pahrump')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (44, 9, 'bathsheba')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (45, 9, 'hami')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (46, 9, 'talnakh')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (47, 9, 'kidal')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (48, 9, 'pangnirtung')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (49, 9, 'yuancheng')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (0, 10, 'salalah')
# -----------------------------
# Data retrieval complete
# ...
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (34, 10, 'bubaque')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (35, 10, 'puerto escondido')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (36, 10, 'zykovo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (37, 10, 'rio grande')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (38, 10, 'isla mujeres')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (39, 10, 'inzhavino')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (40, 10, 'tecoanapa')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (41, 10, 'loandjili')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (42, 10, 'saint-pierre')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (43, 10, 'sakakah')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (44, 10, 'la libertad')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (45, 10, 'thinadhoo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (46, 10, 'rungata')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (47, 10, 'fukue')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (48, 10, 'abakaliki')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (49, 10, 'nanning')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (0, 11, 'pradopolis')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (1, 11, 'bengkulu')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (2, 11, 'lorengau')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (3, 11, 'awjilah')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (4, 11, 'tanabe')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (5, 11, 'grandview')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (6, 11, 'broken hill')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (7, 11, 'vrangel')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (8, 11, 'saint-leu')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (9, 11, 'kawalu')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (10, 11, 'aksarka')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (11, 11, 'nantucket')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (12, 11, 'aberlour')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (13, 11, 'umm kaddadah')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (14, 11, 'conceicao do araguaia')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (15, 11, 'shieli')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (16, 11, 'tanjong karang')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (17, 11, 'labutta')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (18, 11, 'egvekinot')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (19, 11, 'college')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (20, 11, 'camana')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (21, 11, 'huarmey')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (22, 11, 'murgab')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (23, 11, 'kiunga')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (24, 11, 'gat')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (25, 11, 'khartoum')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (26, 11, 'hofn')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (27, 11, 'san quintin')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (28, 11, 'yibin')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (29, 11, 'kuche')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (30, 11, 'salas')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (31, 11, 'middle island')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (32, 11, 'dzhebariki-khaya')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (33, 11, 'puro')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (34, 11, 'bud')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (35, 11, 'shache')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (36, 11, 'pisco')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (37, 11, 'mosquera')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (38, 11, 'coihaique')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (39, 11, 'jennings')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (40, 11, 'iracoubo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (41, 11, 'yeppoon')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (42, 11, 'port lincoln')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (43, 11, 'aksu')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (44, 11, 'grand centre')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (45, 11, 'soskovo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (46, 11, 'russell')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (47, 11, 'port keats')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (48, 11, 'superior')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (49, 11, 'agalteca')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (0, 12, 'nhulunbuy')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (1, 12, 'severnoye')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (2, 12, 'hue')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (3, 12, 'kupang')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (4, 12, 'sechura')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (5, 12, 'vangaindrano')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (6, 12, 'canto do buriti')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (7, 12, 'port blair')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (8, 12, 'sisimiut')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (9, 12, 'abu samrah')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (10, 12, 'henties bay')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (11, 12, 'kashi')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (12, 12, 'ilabaya')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (13, 12, 'greenfield')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (14, 12, 'calimete')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (15, 12, 'velsk')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (16, 12, 'bagua grande')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (17, 12, 'savonlinna')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (18, 12, 'portlethen')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (19, 12, 'tres coracoes')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (20, 12, 'callaway')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (21, 12, 'sitka')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (22, 12, 'port shepstone')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (23, 12, 'tigil')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (24, 12, 'canutama')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (25, 12, 'deputatskiy')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (26, 12, 'zima')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (27, 12, 'pacasmayo')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (28, 12, 'bac lieu')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (29, 12, 'bahir dar')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (30, 12, 'voyvozh')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (31, 12, 'komsomolskiy')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (32, 12, 'vereshchagino')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (33, 12, 'palafrugell')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (34, 12, 'udachnyy')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (35, 12, 'atambua')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (36, 12, 'biskamzha')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (37, 12, 'asilah')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (38, 12, 'sochi')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (39, 12, 'geraldton')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (40, 12, 'vostok')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (41, 12, 'sao francisco de paula')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (42, 12, 'kendari')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (43, 12, 'ranong')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (44, 12, 'broome')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (45, 12, 'yenagoa')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (46, 12, 'georgiyevka')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (47, 12, 'frontera')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (48, 12, 'ituni')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (49, 12, 'ciudad bolivar')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (0, 13, 'belmonte')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (1, 13, 'vicuna')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (2, 13, 'skegness')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (3, 13, 'chutung')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (4, 13, 'port hedland')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (5, 13, 'graaff-reinet')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (6, 13, 'gainesville')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (7, 13, 'joshimath')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (8, 13, 'puerto ayacucho')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (9, 13, 'manbij')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (10, 13, 'chagda')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (11, 13, 'zaria')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (12, 13, 'galle')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (13, 13, 'richards bay')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (14, 13, 'warqla')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (15, 13, 'cody')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (16, 13, 'vallenar')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (17, 13, 'karaul')
# city not found
# -----------------------------
# Data retrieval complete
# ------------------------------
# (18, 13, 'bontang')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (19, 13, 'jalalabad')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (20, 13, 'nizhniy kuranakh')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (21, 13, 'burnie')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (22, 13, 'yaya')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (23, 13, 'mersing')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (24, 13, 'kaset sombun')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (25, 13, 'tulun')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (26, 13, 'marawi')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (27, 13, 'lady frere')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (28, 13, 'maningrida')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (29, 13, 'mwinilunga')
# -----------------------------
# Data retrieval complete
# ------------------------------
# (30, 13, 'shangqiu')
# -----------------------------
# Data retrieval complete
# ------------------------------
